# %% [markdown]
# # WELCOME TO EMMA'S WORLD
# ## This is an introduction to Emma Murray, the most enthusiastic knitter you've never known
# <p> Her name is Emma Murray, she works as graphic designer for Meininger. She is 26 years old and loves to Knit</p>

# %%
name = input("Enter her name: ")
# Out:
# Enter her name: Emma

# %% [markdown]
# <font color = blue>**Image of Emma**</color> ![old_lady.jpg](attachment:old_lady.jpg)

# %% [markdown]
# ![fishing.boats_.jpg](attachment:fishing.boats_.jpg)

# %% [markdown]
#  - <font color = black>On the ~~last day~~ first day, we will have to see the famous Sicilian vineyards.</black>
#  - <font color = red> The second day will be reserved for the Islands beaches, and lots of swimming.</red>
#  - <font color = orange>On the third day, because of her love for arts, we will see some of architectures and also some art works.</color>
#  - <font color = green>This link gives you an idea of more things planned for the trip</color> [YOUTUBE](https://www.youtube.com/watch?v=zlwdk5IGPRU)

# %% [markdown]
# 1. I used a Header with one # and also a sub-header with double #
# 2. Next, I had a function that asked the user for her name
# 3. I was able to add an image using the Edit, Insert Image
# 4. I was able to add bullet points or unordered list.
# 5. I used the markdown </font color/> to change color of texts.
# 6. And lastly, I used an orderd list to write the annotations I used.
