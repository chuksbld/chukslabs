# %% [markdown]
# # Using Pandas

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 200)
## to make it possible to display multiple output inside one cell 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# <b>load the data from the vehicles.csv file into pandas data frame

# %%
## Your Code here
vehicles_df = pd.read_csv("data/vehicles.csv")
vehicles_df
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %% [markdown]
# First exploration of the dataset:
#
# - How many observations does it have?
# - Look at all the columns: do you understand what they mean?
# - Look at the raw data: do you see anything weird?
# - Look at the data types: are they the expected ones for the information the column contains?

# %%
#To check for how many observations there are
#Use the .info() function

vehicles_df.info()
# There are 3592 rows in the observation
print("\n")
#Observe the columns only
print(vehicles_df.columns, "\n")

#observing the raw data to look for outliers
vehicles_df.describe()

#Viewing the data types
type(vehicles_df.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
#  14  Fuel Cost/Year           35952 non-null  int64
# dtypes: float64(4), int64(5), object(6)
# memory usage: 4.1+ MB
#
#
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')
#               Year  Engine Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000         35952.000000  35952.000000       35952.000000
# mean    2000.71640             3.338493      5.765076          17.609056
# std       10.08529             1.359395      1.755268           4.467283
# min     1984.00000             0.600000      2.000000           0.060000
# 25%     1991.00000             2.200000      4.000000          14.699423
# 50%     2001.00000             3.000000      6.000000          17.347895
# 75%     2010.00000             4.300000      6.000000          20.600625
# max     2017.00000             8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# min        6.000000      9.000000      7.000000                37.000000
# 25%       15.000000     20.000000     16.000000               395.000000
# 50%       17.000000     24.000000     19.000000               467.736842
# 75%       20.000000     27.000000     23.000000               555.437500
# max       58.000000     61.000000     56.000000              1269.571429
#
#        Fuel Cost/Year
# count    35952.000000
# mean      1892.598465
# std        506.958627
# min        600.000000
# 25%       1500.000000
# 50%       1850.000000
# 75%       2200.000000
# max       5800.000000
# pandas.core.series.Series

# %% [markdown]
# ### Cleaning and wrangling data
#
# - Some car brand names refer to the same brand. Replace all brand names that contain the word "Dutton" for simply "Dutton". If you find similar examples, clean their names too. Use `loc` with boolean indexing.
#
# - Convert CO2 Emissions from Grams/Mile to Grams/Km
#
# - Create a binary column that solely indicates if the transmission of a car is automatic or manual. Use `pandas.Series.str.startswith` and .
#
# - convert MPG columns to km_per_liter

# %% [markdown]
# Note:
# <br>Converting Grams/Mile to Grams/Km
#
# 1 Mile = 1.60934 Km
#
# Converting Gallons to Liters
#
# 1 Gallon = 3.78541 Liters

# %%
# I Search and replace Brand names that contain Dutton
vehicles_df[vehicles_df.Make.str.contains('Dutton')]
vehicles_df.loc[vehicles_df['Make'].str.contains('Dutton', case = False), 'Make'] = 'Dutton'
print(vehicles_df)
print('\n')


# Converting CO2 Emissions from Grams/Mile to Grams/Km
vehicles_df['CO2 Emission Grams/Km'] = vehicles_df['CO2 Emission Grams/Mile'] / 1.60934
print('\n')


#Binary column that solely indicates if transmission is manual or automatic
def trans_replace(name):
    if name.startswith("A"):
        return 1
    else:
        return 0

vehicles_df["Transmission 1/0"] =vehicles_df.Transmission.apply(trans_replace)
vehicles_df                 
print('\n')

#convert MPG columns to km_per_liter
vehicles_df ["City KPL"] = vehicles_df["City MPG"] / 3.78541
vehicles_df['Highway KPL'] = vehicles_df['Highway MPG'] / 3.78541
vehicles_df['Combined KPL'] = vehicles_df['Combined MPG'] / 3.78541
# Out:
#          Make               Model  Year  Engine Displacement  Cylinders  \
# 11012  Dutton       Funeral Coach  1985                  4.1        8.0
# 30164  Dutton  Funeral Coach  2WD  1984                  6.0        8.0
# 31754  Dutton  Funeral Coach  2WD  1984                  6.0        8.0
#
#           Transmission         Drivetrain                Vehicle Class  \
# 11012  Automatic 4-spd  Front-Wheel Drive     Special Purpose Vehicles
# 30164  Automatic 3-spd      2-Wheel Drive  Special Purpose Vehicle 2WD
# 31754  Automatic 3-spd      2-Wheel Drive  Special Purpose Vehicle 2WD
#
#       Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 11012   Regular          19.388824        15           21            17
# 30164   Regular          32.961000         9           11            10
# 31754   Regular          32.961000        10           11            10
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year  CO2 Emission Grams/Km  \
# 11012               522.764706            1950             324.831736
# 30164               888.700000            3350             552.213951
# 31754               888.700000            3350             552.213951
#
#        Transmission 1/0  City KPL  Highway KPL  Combined KPL
# 11012                 1  3.962583     5.547616      4.490927
# 30164                 1  2.377550     2.905894      2.641722
# 31754                 1  2.641722     2.905894      2.641722
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year  \
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
#        CO2 Emission Grams/Km  Transmission 1/0  City KPL  Highway KPL  \
# 0                 324.831736                 1  4.755099     4.490927
# 1                 424.779962                 1  3.434238     3.434238
# 2                 345.133719                 1  4.226755     4.490927
# 3                 424.779962                 1  3.434238     3.434238
# 4                 345.133719                 1  3.698410     5.547616
# ...                      ...               ...       ...          ...
# 35947             151.614948                 1  8.981854    10.038543
# 35948             150.993575                 1  8.981854    10.038543
# 35949             151.614948                 1  8.981854    10.038543
# 35950             152.857693                 1  8.981854    10.302715
# 35951             158.450048                 0  8.453510    10.302715
#
#        Combined KPL
# 0          4.490927
# 1          3.434238
# 2          4.226755
# 3          3.434238
# 4          4.226755
# ...             ...
# 35947      9.510198
# 35948      9.510198
# 35949      9.510198
# 35950      9.510198
# 35951      9.246026
#
# [35952 rows x 20 columns]
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year  \
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
#        CO2 Emission Grams/Km  Transmission 1/0  City KPL  Highway KPL  \
# 0                 324.831736                 1  4.755099     4.490927
# 1                 424.779962                 1  3.434238     3.434238
# 2                 345.133719                 1  4.226755     4.490927
# 3                 424.779962                 1  3.434238     3.434238
# 4                 345.133719                 1  3.698410     5.547616
# ...                      ...               ...       ...          ...
# 35947             151.614948                 1  8.981854    10.038543
# 35948             150.993575                 1  8.981854    10.038543
# 35949             151.614948                 1  8.981854    10.038543
# 35950             152.857693                 1  8.981854    10.302715
# 35951             158.450048                 0  8.453510    10.302715
#
#        Combined KPL
# 0          4.490927
# 1          3.434238
# 2          4.226755
# 3          3.434238
# 4          4.226755
# ...             ...
# 35947      9.510198
# 35948      9.510198
# 35949      9.510198
# 35950      9.510198
# 35951      9.246026
#
# [35952 rows x 20 columns]

# %% [markdown]
# ### Gathering insights:
#
# - How many car makers are there? How many models? Which car maker has the most cars in the dataset?
#
# - When were these cars made? How big is the engine of these cars?
#
# - What's the frequency of different transmissions, drivetrains and fuel types?
#
# - What's the car that consumes the least/most fuel?

# %%
# How many car makers are there?
len(vehicles_df['Make'].unique())

#How many models?
len(vehicles_df['Model'].unique())

#Which car maker has the most cars in the dataset?
vehicles_df['Make'].mode()
# Out:
# 125
# 3608
# 0    Chevrolet
# Name: Make, dtype: object

# %%
#years cars were made
vehicles_df.iloc[ : , [0,2]]

#how big is the engine
vehicles_df.iloc[ : , [0,4]]

#frequency of different transmissions, drivetrains and fuel types
vehicles_df2 = vehicles_df.groupby(['Transmission','Drivetrain','Fuel Type']).count()
vehicles_df2
# Out:
#                    Make  Year
# 0            AM General  1984
# 1            AM General  1984
# 2            AM General  1985
# 3            AM General  1985
# 4      ASC Incorporated  1987
# ...                 ...   ...
# 35947             smart  2013
# 35948             smart  2014
# 35949             smart  2015
# 35950             smart  2016
# 35951             smart  2016
#
# [35952 rows x 2 columns]
#                    Make  Cylinders
# 0            AM General        4.0
# 1            AM General        6.0
# 2            AM General        4.0
# 3            AM General        6.0
# 4      ASC Incorporated        6.0
# ...                 ...        ...
# 35947             smart        3.0
# 35948             smart        3.0
# 35949             smart        3.0
# 35950             smart        3.0
# 35951             smart        3.0
#
# [35952 rows x 2 columns]
#                                                            Make  Model  Year  \
# Transmission Drivetrain        Fuel Type
# Auto (AV)    Front-Wheel Drive Premium Gas or Electricity     2      2     2
# Auto (AV-S6) Rear-Wheel Drive  Premium                        1      1     1
# Auto (AV-S8) All-Wheel Drive   Premium                        1      1     1
# Auto(A1)     Rear-Wheel Drive  Premium Gas or Electricity     1      1     1
# Auto(AM-S6)  All-Wheel Drive   Premium                       21     21    21
# ...                                                         ...    ...   ...
# Manual 6-spd Rear-Wheel Drive  Regular                      161    161   161
# Manual 7-spd 4-Wheel Drive     Premium                       33     33    33
#              All-Wheel Drive   Premium                        2      2     2
#              Rear-Wheel Drive  Premium                       33     33    33
# Manual(M7)   Rear-Wheel Drive  Premium                        3      3     3
#
#                                                            Engine Displacement  \
# Transmission Drivetrain        Fuel Type
# Auto (AV)    Front-Wheel Drive Premium Gas or Electricity                    2
# Auto (AV-S6) Rear-Wheel Drive  Premium                                       1
# Auto (AV-S8) All-Wheel Drive   Premium                                       1
# Auto(A1)     Rear-Wheel Drive  Premium Gas or Electricity                    1
# Auto(AM-S6)  All-Wheel Drive   Premium                                      21
# ...                                                                        ...
# Manual 6-spd Rear-Wheel Drive  Regular                                     161
# Manual 7-spd 4-Wheel Drive     Premium                                      33
#              All-Wheel Drive   Premium                                       2
#              Rear-Wheel Drive  Premium                                      33
# Manual(M7)   Rear-Wheel Drive  Premium                                       3
#
#                                                            Cylinders  \
# Transmission Drivetrain        Fuel Type
# Auto (AV)    Front-Wheel Drive Premium Gas or Electricity          2
# Auto (AV-S6) Rear-Wheel Drive  Premium                             1
# Auto (AV-S8) All-Wheel Drive   Premium                             1
# Auto(A1)     Rear-Wheel Drive  Premium Gas or Electricity          1
# Auto(AM-S6)  All-Wheel Drive   Premium                            21
# ...                                                              ...
# Manual 6-spd Rear-Wheel Drive  Regular                           161
# Manual 7-spd 4-Wheel Drive     Premium                            33
#              All-Wheel Drive   Premium                             2
#              Rear-Wheel Drive  Premium                            33
# Manual(M7)   Rear-Wheel Drive  Premium                             3
#
#                                                            Vehicle Class  \
# Transmission Drivetrain        Fuel Type
# Auto (AV)    Front-Wheel Drive Premium Gas or Electricity              2
# Auto (AV-S6) Rear-Wheel Drive  Premium                                 1
# Auto (AV-S8) All-Wheel Drive   Premium                                 1
# Auto(A1)     Rear-Wheel Drive  Premium Gas or Electricity              1
# Auto(AM-S6)  All-Wheel Drive   Premium                                21
# ...                                                                  ...
# Manual 6-spd Rear-Wheel Drive  Regular                               161
# Manual 7-spd 4-Wheel Drive     Premium                                33
#              All-Wheel Drive   Premium                                 2
#              Rear-Wheel Drive  Premium                                33
# Manual(M7)   Rear-Wheel Drive  Premium                                 3
#
#                                                            Fuel Barrels/Year  \
# Transmission Drivetrain        Fuel Type
# Auto (AV)    Front-Wheel Drive Premium Gas or Electricity                  2
# Auto (AV-S6) Rear-Wheel Drive  Premium                                     1
# Auto (AV-S8) All-Wheel Drive   Premium                                     1
# Auto(A1)     Rear-Wheel Drive  Premium Gas or Electricity                  1
# Auto(AM-S6)  All-Wheel Drive   Premium                                    21
# ...                                                                      ...
# Manual 6-spd Rear-Wheel Drive  Regular                                   161
# Manual 7-spd 4-Wheel Drive     Premium                                    33
#              All-Wheel Drive   Premium                                     2
#              Rear-Wheel Drive  Premium                                    33
# Manual(M7)   Rear-Wheel Drive  Premium                                     3
#
#                                                            City MPG  \
# Transmission Drivetrain        Fuel Type
# Auto (AV)    Front-Wheel Drive Premium Gas or Electricity         2
# Auto (AV-S6) Rear-Wheel Drive  Premium                            1
# Auto (AV-S8) All-Wheel Drive   Premium                            1
# Auto(A1)     Rear-Wheel Drive  Premium Gas or Electricity         1
# Auto(AM-S6)  All-Wheel Drive   Premium                           21
# ...                                                             ...
# Manual 6-spd Rear-Wheel Drive  Regular                          161
# Manual 7-spd 4-Wheel Drive     Premium                           33
#              All-Wheel Drive   Premium                            2
#              Rear-Wheel Drive  Premium                           33
# Manual(M7)   Rear-Wheel Drive  Premium                            3
#
#                                                            Highway MPG  \
# Transmission Drivetrain        Fuel Type
# Auto (AV)    Front-Wheel Drive Premium Gas or Electricity            2
# Auto (AV-S6) Rear-Wheel Drive  Premium                               1
# Auto (AV-S8) All-Wheel Drive   Premium                               1
# Auto(A1)     Rear-Wheel Drive  Premium Gas or Electricity            1
# Auto(AM-S6)  All-Wheel Drive   Premium                              21
# ...                                                                ...
# Manual 6-spd Rear-Wheel Drive  Regular                             161
# Manual 7-spd 4-Wheel Drive     Premium                              33
#              All-Wheel Drive   Premium                               2
#              Rear-Wheel Drive  Premium                              33
# Manual(M7)   Rear-Wheel Drive  Premium                               3
#
#                                                            Combined MPG  \
# Transmission Drivetrain        Fuel Type
# Auto (AV)    Front-Wheel Drive Premium Gas or Electricity             2
# Auto (AV-S6) Rear-Wheel Drive  Premium                                1
# Auto (AV-S8) All-Wheel Drive   Premium                                1
# Auto(A1)     Rear-Wheel Drive  Premium Gas or Electricity             1
# Auto(AM-S6)  All-Wheel Drive   Premium                               21
# ...                                                                 ...
# Manual 6-spd Rear-Wheel Drive  Regular                              161
# Manual 7-spd 4-Wheel Drive     Premium                               33
#              All-Wheel Drive   Premium                                2
#              Rear-Wheel Drive  Premium                               33
# Manual(M7)   Rear-Wheel Drive  Premium                                3
#
#                                                            CO2 Emission Grams/Mile  \
# Transmission Drivetrain        Fuel Type
# Auto (AV)    Front-Wheel Drive Premium Gas or Electricity                        2
# Auto (AV-S6) Rear-Wheel Drive  Premium                                           1
# Auto (AV-S8) All-Wheel Drive   Premium                                           1
# Auto(A1)     Rear-Wheel Drive  Premium Gas or Electricity                        1
# Auto(AM-S6)  All-Wheel Drive   Premium                                          21
# ...                                                                            ...
# Manual 6-spd Rear-Wheel Drive  Regular                                         161
# Manual 7-spd 4-Wheel Drive     Premium                                          33
#              All-Wheel Drive   Premium                                           2
#              Rear-Wheel Drive  Premium                                          33
# Manual(M7)   Rear-Wheel Drive  Premium                                           3
#
#                                                            Fuel Cost/Year  \
# Transmission Drivetrain        Fuel Type
# Auto (AV)    Front-Wheel Drive Premium Gas or Electricity               2
# Auto (AV-S6) Rear-Wheel Drive  Premium                                  1
# Auto (AV-S8) All-Wheel Drive   Premium                                  1
# Auto(A1)     Rear-Wheel Drive  Premium Gas or Electricity               1
# Auto(AM-S6)  All-Wheel Drive   Premium                                 21
# ...                                                                   ...
# Manual 6-spd Rear-Wheel Drive  Regular                                161
# Manual 7-spd 4-Wheel Drive     Premium                                 33
#              All-Wheel Drive   Premium                                  2
#              Rear-Wheel Drive  Premium                                 33
# Manual(M7)   Rear-Wheel Drive  Premium                                  3
#
#                                                            CO2 Emission Grams/Km  \
# Transmission Drivetrain        Fuel Type
# Auto (AV)    Front-Wheel Drive Premium Gas or Electricity                      2
# Auto (AV-S6) Rear-Wheel Drive  Premium                                         1
# Auto (AV-S8) All-Wheel Drive   Premium                                         1
# Auto(A1)     Rear-Wheel Drive  Premium Gas or Electricity                      1
# Auto(AM-S6)  All-Wheel Drive   Premium                                        21
# ...                                                                          ...
# Manual 6-spd Rear-Wheel Drive  Regular                                       161
# Manual 7-spd 4-Wheel Drive     Premium                                        33
#              All-Wheel Drive   Premium                                         2
#              Rear-Wheel Drive  Premium                                        33
# Manual(M7)   Rear-Wheel Drive  Premium                                         3
#
#                                                            Transmission 1/0  \
# Transmission Drivetrain        Fuel Type
# Auto (AV)    Front-Wheel Drive Premium Gas or Electricity                 2
# Auto (AV-S6) Rear-Wheel Drive  Premium                                    1
# Auto (AV-S8) All-Wheel Drive   Premium                                    1
# Auto(A1)     Rear-Wheel Drive  Premium Gas or Electricity                 1
# Auto(AM-S6)  All-Wheel Drive   Premium                                   21
# ...                                                                     ...
# Manual 6-spd Rear-Wheel Drive  Regular                                  161
# Manual 7-spd 4-Wheel Drive     Premium                                   33
#              All-Wheel Drive   Premium                                    2
#              Rear-Wheel Drive  Premium                                   33
# Manual(M7)   Rear-Wheel Drive  Premium                                    3
#
#                                                            City KPL  \
# Transmission Drivetrain        Fuel Type
# Auto (AV)    Front-Wheel Drive Premium Gas or Electricity         2
# Auto (AV-S6) Rear-Wheel Drive  Premium                            1
# Auto (AV-S8) All-Wheel Drive   Premium                            1
# Auto(A1)     Rear-Wheel Drive  Premium Gas or Electricity         1
# Auto(AM-S6)  All-Wheel Drive   Premium                           21
# ...                                                             ...
# Manual 6-spd Rear-Wheel Drive  Regular                          161
# Manual 7-spd 4-Wheel Drive     Premium                           33
#              All-Wheel Drive   Premium                            2
#              Rear-Wheel Drive  Premium                           33
# Manual(M7)   Rear-Wheel Drive  Premium                            3
#
#                                                            Highway KPL  \
# Transmission Drivetrain        Fuel Type
# Auto (AV)    Front-Wheel Drive Premium Gas or Electricity            2
# Auto (AV-S6) Rear-Wheel Drive  Premium                               1
# Auto (AV-S8) All-Wheel Drive   Premium                               1
# Auto(A1)     Rear-Wheel Drive  Premium Gas or Electricity            1
# Auto(AM-S6)  All-Wheel Drive   Premium                              21
# ...                                                                ...
# Manual 6-spd Rear-Wheel Drive  Regular                             161
# Manual 7-spd 4-Wheel Drive     Premium                              33
#              All-Wheel Drive   Premium                               2
#              Rear-Wheel Drive  Premium                              33
# Manual(M7)   Rear-Wheel Drive  Premium                               3
#
#                                                            Combined KPL
# Transmission Drivetrain        Fuel Type
# Auto (AV)    Front-Wheel Drive Premium Gas or Electricity             2
# Auto (AV-S6) Rear-Wheel Drive  Premium                                1
# Auto (AV-S8) All-Wheel Drive   Premium                                1
# Auto(A1)     Rear-Wheel Drive  Premium Gas or Electricity             1
# Auto(AM-S6)  All-Wheel Drive   Premium                               21
# ...                                                                 ...
# Manual 6-spd Rear-Wheel Drive  Regular                              161
# Manual 7-spd 4-Wheel Drive     Premium                               33
#              All-Wheel Drive   Premium                                2
#              Rear-Wheel Drive  Premium                               33
# Manual(M7)   Rear-Wheel Drive  Premium                                3
#
# [324 rows x 17 columns]

# %%
#The car that consumes the least fuel
vehicles_df['Fuel Barrels/Year'].min()

#The car that consumes the most fuel
vehicles_df['Fuel Barrels/Year'].max()
# Out:
# 0.06
# 47.08714285714285

# %%
#When were these cars made? 
vehicles_df.iloc[: , 2]
# Out:
# 0        1984
# 1        1984
# 2        1985
# 3        1985
# 4        1987
#          ...
# 35947    2013
# 35948    2014
# 35949    2015
# 35950    2016
# 35951    2016
# Name: Year, Length: 35952, dtype: int64

# %% [markdown]
# <b> (Optional)

# %% [markdown]
# What brand has the worse CO2 Emissions on average?
#
# Hint: use the function `sort_values()`

# %%
## your Code here

vehicles_df3 = vehicles_df.sort_values(by=['Make','CO2 Emission Grams/Km'], ascending = False)
print(vehicles_df3)
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 35939             smart     fortwo cabriolet  2017                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
# 35938             smart     fortwo cabriolet  2017                  0.9
# 35932             smart     fortwo cabriolet  2010                  1.0
# 35933             smart     fortwo cabriolet  2011                  1.0
# ...                 ...                  ...   ...                  ...
# 4      ASC Incorporated                  GNX  1987                  3.8
# 1            AM General     FJ8c Post Office  1984                  4.2
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
#
#        Cylinders     Transmission        Drivetrain  \
# 35939        3.0     Manual 5-spd  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
# 35938        3.0        Auto(AM6)  Rear-Wheel Drive
# 35932        3.0        Auto(AM5)  Rear-Wheel Drive
# 35933        3.0        Auto(AM5)  Rear-Wheel Drive
# ...          ...              ...               ...
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 0            4.0  Automatic 3-spd     2-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 35939                  Two Seaters   Premium           9.694412        31
# 35951                  Two Seaters   Premium           9.417429        32
# 35938                  Two Seaters   Premium           9.417429        33
# 35932                  Two Seaters   Premium           9.155833        33
# 35933                  Two Seaters   Premium           9.155833        33
# ...                            ...       ...                ...       ...
# 4                     Midsize Cars   Premium          20.600625        14
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year  \
# 35939           38            34               258.000000            1200
# 35951           39            35               255.000000            1150
# 35938           38            35               251.000000            1150
# 35932           41            36               246.861111            1100
# 35933           41            36               246.861111            1100
# ...            ...           ...                      ...             ...
# 4               21            16               555.437500            2550
# 1               13            13               683.615385            2550
# 3               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 0               17            17               522.764706            1950
#
#        CO2 Emission Grams/Km  Transmission 1/0  City KPL  Highway KPL  \
# 35939             160.314166                 0  8.189337    10.038543
# 35951             158.450048                 0  8.453510    10.302715
# 35938             155.964557                 1  8.717682    10.038543
# 35932             153.392764                 1  8.717682    10.831059
# 35933             153.392764                 1  8.717682    10.831059
# ...                      ...               ...       ...          ...
# 4                 345.133719                 1  3.698410     5.547616
# 1                 424.779962                 1  3.434238     3.434238
# 3                 424.779962                 1  3.434238     3.434238
# 2                 345.133719                 1  4.226755     4.490927
# 0                 324.831736                 1  4.755099     4.490927
#
#        Combined KPL
# 35939      8.981854
# 35951      9.246026
# 35938      9.246026
# 35932      9.510198
# 35933      9.510198
# ...             ...
# 4          4.226755
# 1          3.434238
# 3          3.434238
# 2          4.226755
# 0          4.490927
#
# [35952 rows x 20 columns]

# %% [markdown]
# Do cars with automatic transmission consume more fuel than cars with manual transmission on average?

# %%
## Your Code is here 
def trans(x):
    if x.startswith ('A'):
        return 'Automatic'
    elif x.startswith('M'):
        return 'Manual'
    else: pass
vehicles_df['Trans'] = vehicles_df['Transmission'].apply(trans)

# %%
vehicles_df.groupby(['Trans'])['CO2 Emission Grams/Km'].mean().sort_values(ascending = False)
# Out:
# Trans
# Automatic    302.853002
# Manual       279.718227
# Name: CO2 Emission Grams/Km, dtype: float64
